# %%
import os
import numpy as np
import pandas as pd
import librosa
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers, models
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
import joblib

# %%
DATASET_PATH = "C:/Users/Estudio/Documents/ParcialFinalDeepLearning/UrbanSound8K/UrbanSound8k" # ajusta si tu dataset está en otro lugar
METADATA_CSV = os.path.join(DATASET_PATH, "metadata", "UrbanSound8K.csv")
SAMPLE_RATE = 16000            # YAMNet usa 16 kHz
DURATION = 4.0                 # segundos (igual que usabas)
NUM_CLASSES = 10
BATCH_SIZE = 32
EPOCHS = 20
RANDOM_SEED = 42

# --- Cargar metadata ---
metadata = pd.read_csv(METADATA_CSV)
metadata.columns = metadata.columns.str.strip()

# --- Cargar YAMNet (TF-Hub) ---
# Nota: esto descargará el modelo la primera vez. Requiere internet.
yamnet = hub.load("https://tfhub.dev/google/yamnet/1")
# yamnet(waveform) devuelve (scores, embeddings, spectrogram)
print("YAMNet cargado.")
# Out:
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# YAMNet cargado.

# %%
def load_audio_for_yamnet(path, sr=SAMPLE_RATE, duration=DURATION):
    y, orig_sr = librosa.load(path, sr=None, mono=True)
    # Remuestrear si es necesario
    if orig_sr != sr:
        y = librosa.resample(y, orig_sr=orig_sr, target_sr=sr)
    max_len = int(sr * duration)
    if len(y) < max_len:
        y = np.pad(y, (0, max_len - len(y)))
    else:
        y = y[:max_len]
    # YAMNet espera float32 en [-1.0, 1.0]
    return y.astype(np.float32)

def extract_yamnet_embedding(waveform):
    """
    waveform: 1D numpy array a 16kHz float32
    devuelve: embedding agregado del clip (mean + std concatenadas)
    """
    # yamnet espera un tensor shape (num_samples,)
    scores, embeddings, spectrogram = yamnet(waveform)
    # embeddings: (num_patches, 1024)
    emb_np = embeddings.numpy()
    mean = np.mean(emb_np, axis=0)
    std = np.std(emb_np, axis=0)
    return np.concatenate([mean, std])  # tamaño 2048

# %%
# --- Precomputar features para todo el dataset (puede tardar) ---
features = []
labels = []
filepaths = []

for idx, row in tqdm(metadata.iterrows(), total=len(metadata), desc="Extrayendo features"):
    fold = int(row["fold"])
    filename = row["slice_file_name"]
    class_id = int(row["classID"])
    audio_path = os.path.join(DATASET_PATH, "audio", f"fold{fold}", filename)
    if not os.path.exists(audio_path):
        # opcional: omitir o lanzar error
        print("No encontrado:", audio_path)
        continue
    y = load_audio_for_yamnet(audio_path)
    emb = extract_yamnet_embedding(y)
    features.append(emb)
    labels.append(class_id)
    filepaths.append(audio_path)

features = np.array(features)   # (N, 2048)
labels = np.array(labels)
print("Features shape:", features.shape)
# Out:
# Extrayendo features: 100%|██████████| 8732/8732 [03:30<00:00, 41.47it/s]
# Features shape: (8732, 2048)

# %%
# --- Normalizar features (fit sobre todo; para CV perfecto usar pipeline) ---
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Guardar scaler para inferencia
joblib.dump(scaler, "yamnet_scaler.joblib")
# Out:
# ['yamnet_scaler.joblib']

# %%
# --- Clasificador simple (Dense) ---
def make_classifier_model(input_dim, num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(512, activation="relu")(inputs)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# %%
# --- Validación cruzada estratificada 10-fold ---
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=RANDOM_SEED)
accs = []
fold_idx = 0

for train_idx, test_idx in skf.split(features_scaled, labels):
    fold_idx += 1
    print(f"\n=== Fold {fold_idx} ===")
    X_train, X_test = features_scaled[train_idx], features_scaled[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    model = make_classifier_model(input_dim=X_train.shape[1], num_classes=NUM_CLASSES)

    # EarlyStopping para no sobreentrenar
    es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=4, restore_best_weights=True)

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[es],
        verbose=2
    )

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold {fold_idx} accuracy: {acc:.4f}")
    accs.append(acc)
# Out:
# === Fold 1 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6525 - loss: 1.3702 - val_accuracy: 0.7620 - val_loss: 0.7014
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7443 - loss: 0.7804 - val_accuracy: 0.7757 - val_loss: 0.5785
# Epoch 3/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7826 - loss: 0.6500 - val_accuracy: 0.8078 - val_loss: 0.5767
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8016 - loss: 0.5830 - val_accuracy: 0.8318 - val_loss: 0.4637
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8195 - loss: 0.5322 - val_accuracy: 0.8398 - val_loss: 0.4731
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8285 - loss: 0.4998 - val_accuracy: 0.8558 - val_loss: 0.4594
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8433 - loss: 0.4664 - val_accuracy: 0.8764 - val_loss: 0.3842
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8475 - loss: 0.4482 - val_accuracy: 0.8444 - val_loss: 0.4000
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8517 - loss: 0.4315 - val_accuracy: 0.8719 - val_loss: 0.3883
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8632 - loss: 0.4104 - val_accuracy: 0.8902 - val_loss: 0.3780
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8702 - loss: 0.3713 - val_accuracy: 0.8844 - val_loss: 0.4224
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8735 - loss: 0.3781 - val_accuracy: 0.8833 - val_loss: 0.3571
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8766 - loss: 0.3710 - val_accuracy: 0.8879 - val_loss: 0.3532
# Epoch 14/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8792 - loss: 0.3594 - val_accuracy: 0.8616 - val_loss: 0.4458
# Fold 1 accuracy: 0.8902
#
# === Fold 2 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6611 - loss: 1.4474 - val_accuracy: 0.8135 - val_loss: 0.5869
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7522 - loss: 0.7794 - val_accuracy: 0.8055 - val_loss: 0.5723
# Epoch 3/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7858 - loss: 0.6429 - val_accuracy: 0.8089 - val_loss: 0.5464
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8063 - loss: 0.5897 - val_accuracy: 0.8844 - val_loss: 0.4440
# Epoch 5/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8211 - loss: 0.5270 - val_accuracy: 0.8547 - val_loss: 0.4410
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8367 - loss: 0.4938 - val_accuracy: 0.8581 - val_loss: 0.4318
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8468 - loss: 0.4514 - val_accuracy: 0.8673 - val_loss: 0.3832
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8551 - loss: 0.4272 - val_accuracy: 0.8673 - val_loss: 0.3825
# Fold 2 accuracy: 0.8844
#
# === Fold 3 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6646 - loss: 1.4346 - val_accuracy: 0.7950 - val_loss: 0.5979
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7632 - loss: 0.7573 - val_accuracy: 0.7847 - val_loss: 0.5283
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7834 - loss: 0.6512 - val_accuracy: 0.8419 - val_loss: 0.4747
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8137 - loss: 0.5538 - val_accuracy: 0.8522 - val_loss: 0.4748
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8206 - loss: 0.5191 - val_accuracy: 0.8396 - val_loss: 0.4591
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8379 - loss: 0.4764 - val_accuracy: 0.8820 - val_loss: 0.3955
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8546 - loss: 0.4348 - val_accuracy: 0.8683 - val_loss: 0.3914
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8597 - loss: 0.4244 - val_accuracy: 0.8740 - val_loss: 0.4080
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8636 - loss: 0.4065 - val_accuracy: 0.8900 - val_loss: 0.3431
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8747 - loss: 0.3717 - val_accuracy: 0.9026 - val_loss: 0.3344
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8722 - loss: 0.3774 - val_accuracy: 0.9049 - val_loss: 0.2958
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8837 - loss: 0.3521 - val_accuracy: 0.9175 - val_loss: 0.2644
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8828 - loss: 0.3557 - val_accuracy: 0.8923 - val_loss: 0.3377
# Epoch 14/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8869 - loss: 0.3408 - val_accuracy: 0.9003 - val_loss: 0.3145
# Epoch 15/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8963 - loss: 0.3133 - val_accuracy: 0.9187 - val_loss: 0.2999
# Epoch 16/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8953 - loss: 0.3225 - val_accuracy: 0.9141 - val_loss: 0.2831
# Epoch 17/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8987 - loss: 0.3052 - val_accuracy: 0.9118 - val_loss: 0.2972
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9019 - loss: 0.3047 - val_accuracy: 0.8797 - val_loss: 0.3835
# Epoch 19/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9011 - loss: 0.3074 - val_accuracy: 0.8900 - val_loss: 0.3532
# Fold 3 accuracy: 0.9187
#
# === Fold 4 ===
# Epoch 1/20
# 246/246 - 1s - 5ms/step - accuracy: 0.6632 - loss: 1.4722 - val_accuracy: 0.7881 - val_loss: 0.6318
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7482 - loss: 0.7645 - val_accuracy: 0.8041 - val_loss: 0.6073
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7808 - loss: 0.6623 - val_accuracy: 0.8236 - val_loss: 0.4927
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8066 - loss: 0.5585 - val_accuracy: 0.8477 - val_loss: 0.4614
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8117 - loss: 0.5434 - val_accuracy: 0.8603 - val_loss: 0.4521
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8313 - loss: 0.4879 - val_accuracy: 0.8591 - val_loss: 0.4350
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8355 - loss: 0.4770 - val_accuracy: 0.8499 - val_loss: 0.4374
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8464 - loss: 0.4443 - val_accuracy: 0.8706 - val_loss: 0.4125
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8599 - loss: 0.4145 - val_accuracy: 0.8454 - val_loss: 0.4222
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8658 - loss: 0.4121 - val_accuracy: 0.8900 - val_loss: 0.3938
# Epoch 11/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8626 - loss: 0.3949 - val_accuracy: 0.8969 - val_loss: 0.3550
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8726 - loss: 0.3768 - val_accuracy: 0.8625 - val_loss: 0.3696
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8795 - loss: 0.3548 - val_accuracy: 0.8992 - val_loss: 0.3500
# Epoch 14/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8852 - loss: 0.3422 - val_accuracy: 0.8832 - val_loss: 0.3660
# Epoch 15/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8762 - loss: 0.3716 - val_accuracy: 0.8843 - val_loss: 0.3617
# Epoch 16/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8930 - loss: 0.3295 - val_accuracy: 0.8923 - val_loss: 0.3717
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8888 - loss: 0.3342 - val_accuracy: 0.8820 - val_loss: 0.3828
# Fold 4 accuracy: 0.8992
#
# === Fold 5 ===
# Epoch 1/20
# 246/246 - 1s - 5ms/step - accuracy: 0.6641 - loss: 1.4698 - val_accuracy: 0.7778 - val_loss: 0.6684
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7542 - loss: 0.7652 - val_accuracy: 0.8236 - val_loss: 0.5696
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7900 - loss: 0.6375 - val_accuracy: 0.8293 - val_loss: 0.5067
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8122 - loss: 0.5648 - val_accuracy: 0.8225 - val_loss: 0.5173
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8310 - loss: 0.5071 - val_accuracy: 0.8694 - val_loss: 0.4195
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8393 - loss: 0.4740 - val_accuracy: 0.8786 - val_loss: 0.4427
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8485 - loss: 0.4523 - val_accuracy: 0.8385 - val_loss: 0.4663
# Epoch 8/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8521 - loss: 0.4400 - val_accuracy: 0.8729 - val_loss: 0.3884
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8653 - loss: 0.4090 - val_accuracy: 0.8442 - val_loss: 0.4412
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8680 - loss: 0.3929 - val_accuracy: 0.8797 - val_loss: 0.3946
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8766 - loss: 0.3745 - val_accuracy: 0.8671 - val_loss: 0.4283
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8871 - loss: 0.3425 - val_accuracy: 0.8454 - val_loss: 0.5210
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8824 - loss: 0.3570 - val_accuracy: 0.8843 - val_loss: 0.3873
# Epoch 14/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8934 - loss: 0.3182 - val_accuracy: 0.8751 - val_loss: 0.3970
# Epoch 15/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8926 - loss: 0.3385 - val_accuracy: 0.8958 - val_loss: 0.3487
# Epoch 16/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8974 - loss: 0.3146 - val_accuracy: 0.8900 - val_loss: 0.3854
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8925 - loss: 0.3289 - val_accuracy: 0.8877 - val_loss: 0.3770
# Epoch 18/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9020 - loss: 0.3059 - val_accuracy: 0.8981 - val_loss: 0.3694
# Epoch 19/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9083 - loss: 0.2777 - val_accuracy: 0.8923 - val_loss: 0.3623
# Epoch 20/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9009 - loss: 0.3003 - val_accuracy: 0.8832 - val_loss: 0.3792
# Fold 5 accuracy: 0.8981
#
# === Fold 6 ===
# Epoch 1/20
# 246/246 - 1s - 5ms/step - accuracy: 0.6585 - loss: 1.4185 - val_accuracy: 0.7755 - val_loss: 0.6236
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7517 - loss: 0.7562 - val_accuracy: 0.7973 - val_loss: 0.5848
# Epoch 3/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7889 - loss: 0.6317 - val_accuracy: 0.7869 - val_loss: 0.5815
# Epoch 4/20
# 246/246 - 1s - 5ms/step - accuracy: 0.7977 - loss: 0.5979 - val_accuracy: 0.8614 - val_loss: 0.4722
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8203 - loss: 0.5348 - val_accuracy: 0.8488 - val_loss: 0.4729
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8328 - loss: 0.5074 - val_accuracy: 0.8545 - val_loss: 0.4438
# Epoch 7/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8375 - loss: 0.4740 - val_accuracy: 0.8385 - val_loss: 0.5055
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8502 - loss: 0.4466 - val_accuracy: 0.8465 - val_loss: 0.4819
# Fold 6 accuracy: 0.8614
#
# === Fold 7 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6643 - loss: 1.4282 - val_accuracy: 0.7755 - val_loss: 0.6081
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7567 - loss: 0.7658 - val_accuracy: 0.8053 - val_loss: 0.5771
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7893 - loss: 0.6353 - val_accuracy: 0.8419 - val_loss: 0.4705
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8137 - loss: 0.5532 - val_accuracy: 0.8603 - val_loss: 0.4448
# Epoch 5/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8234 - loss: 0.5128 - val_accuracy: 0.8774 - val_loss: 0.3772
# Epoch 6/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8465 - loss: 0.4678 - val_accuracy: 0.8568 - val_loss: 0.4032
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8523 - loss: 0.4416 - val_accuracy: 0.8751 - val_loss: 0.3595
# Epoch 8/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8555 - loss: 0.4283 - val_accuracy: 0.8820 - val_loss: 0.3514
# Epoch 9/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8653 - loss: 0.3972 - val_accuracy: 0.8855 - val_loss: 0.3221
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8815 - loss: 0.3557 - val_accuracy: 0.8935 - val_loss: 0.3421
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8750 - loss: 0.3843 - val_accuracy: 0.9026 - val_loss: 0.3356
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8809 - loss: 0.3541 - val_accuracy: 0.8946 - val_loss: 0.3165
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8880 - loss: 0.3266 - val_accuracy: 0.8694 - val_loss: 0.3553
# Epoch 14/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8899 - loss: 0.3412 - val_accuracy: 0.8923 - val_loss: 0.3492
# Epoch 15/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8958 - loss: 0.3091 - val_accuracy: 0.9038 - val_loss: 0.3032
# Epoch 16/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8982 - loss: 0.3087 - val_accuracy: 0.8877 - val_loss: 0.3930
# Epoch 17/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9016 - loss: 0.3108 - val_accuracy: 0.9187 - val_loss: 0.2981
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9034 - loss: 0.2947 - val_accuracy: 0.9175 - val_loss: 0.3072
# Epoch 19/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8995 - loss: 0.3103 - val_accuracy: 0.9038 - val_loss: 0.3367
# Epoch 20/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9057 - loss: 0.2985 - val_accuracy: 0.9187 - val_loss: 0.3444
# Fold 7 accuracy: 0.9187
#
# === Fold 8 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6684 - loss: 1.4326 - val_accuracy: 0.7755 - val_loss: 0.6562
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7640 - loss: 0.7565 - val_accuracy: 0.8121 - val_loss: 0.4993
# Epoch 3/20
# 246/246 - 1s - 5ms/step - accuracy: 0.7925 - loss: 0.6301 - val_accuracy: 0.8625 - val_loss: 0.4204
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8113 - loss: 0.5648 - val_accuracy: 0.8614 - val_loss: 0.4233
# Epoch 5/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8278 - loss: 0.5177 - val_accuracy: 0.8557 - val_loss: 0.4057
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8403 - loss: 0.4665 - val_accuracy: 0.8580 - val_loss: 0.3852
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8499 - loss: 0.4487 - val_accuracy: 0.8637 - val_loss: 0.3651
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8575 - loss: 0.4206 - val_accuracy: 0.8797 - val_loss: 0.3253
# Epoch 9/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8673 - loss: 0.4052 - val_accuracy: 0.8992 - val_loss: 0.2988
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8717 - loss: 0.3928 - val_accuracy: 0.8889 - val_loss: 0.3180
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8780 - loss: 0.3871 - val_accuracy: 0.8923 - val_loss: 0.3094
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8840 - loss: 0.3491 - val_accuracy: 0.8877 - val_loss: 0.3246
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8838 - loss: 0.3441 - val_accuracy: 0.8935 - val_loss: 0.3078
# Fold 8 accuracy: 0.8992
#
# === Fold 9 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6578 - loss: 1.4571 - val_accuracy: 0.7801 - val_loss: 0.6317
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7506 - loss: 0.7850 - val_accuracy: 0.7973 - val_loss: 0.5958
# Epoch 3/20
# 246/246 - 1s - 5ms/step - accuracy: 0.7875 - loss: 0.6459 - val_accuracy: 0.8247 - val_loss: 0.5260
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8107 - loss: 0.5688 - val_accuracy: 0.8442 - val_loss: 0.4972
# Epoch 5/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8239 - loss: 0.5166 - val_accuracy: 0.8385 - val_loss: 0.5007
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8389 - loss: 0.4739 - val_accuracy: 0.8740 - val_loss: 0.4126
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8490 - loss: 0.4510 - val_accuracy: 0.8488 - val_loss: 0.4553
# Epoch 8/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8552 - loss: 0.4389 - val_accuracy: 0.8454 - val_loss: 0.4727
# Epoch 9/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8627 - loss: 0.4042 - val_accuracy: 0.8522 - val_loss: 0.4403
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8776 - loss: 0.3762 - val_accuracy: 0.8751 - val_loss: 0.3994
# Epoch 11/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8712 - loss: 0.3791 - val_accuracy: 0.8889 - val_loss: 0.3952
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8790 - loss: 0.3605 - val_accuracy: 0.8809 - val_loss: 0.3982
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8785 - loss: 0.3560 - val_accuracy: 0.8751 - val_loss: 0.4052
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8860 - loss: 0.3477 - val_accuracy: 0.8786 - val_loss: 0.4096
# Epoch 15/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8924 - loss: 0.3327 - val_accuracy: 0.8809 - val_loss: 0.3904
# Fold 9 accuracy: 0.8889
#
# === Fold 10 ===
# Epoch 1/20
# 246/246 - 1s - 5ms/step - accuracy: 0.6584 - loss: 1.4483 - val_accuracy: 0.7606 - val_loss: 0.6556
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7521 - loss: 0.7425 - val_accuracy: 0.8076 - val_loss: 0.5858
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7889 - loss: 0.6254 - val_accuracy: 0.8282 - val_loss: 0.5416
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8090 - loss: 0.5692 - val_accuracy: 0.8603 - val_loss: 0.4819
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8197 - loss: 0.5367 - val_accuracy: 0.8305 - val_loss: 0.5030
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8425 - loss: 0.4681 - val_accuracy: 0.8648 - val_loss: 0.4537
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8499 - loss: 0.4447 - val_accuracy: 0.8763 - val_loss: 0.4303
# Epoch 8/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8497 - loss: 0.4358 - val_accuracy: 0.8648 - val_loss: 0.4167
# Epoch 9/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8580 - loss: 0.4127 - val_accuracy: 0.8751 - val_loss: 0.4139
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8627 - loss: 0.4036 - val_accuracy: 0.8580 - val_loss: 0.4160
# Epoch 11/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8712 - loss: 0.3817 - val_accuracy: 0.8706 - val_loss: 0.4253
# Fold 10 accuracy: 0.8763

# %%
# --- Resultados ---
accs = np.array(accs)
print("\nAccuracies por fold:", accs)
print("Mean accuracy:", accs.mean(), "Std:", accs.std())
# Out:
# Accuracies por fold: [0.8901602  0.88443935 0.91867125 0.89919817 0.89805269 0.8613975
#  0.91867125 0.89919817 0.8888889  0.87628865]
# Mean accuracy: 0.8934966146945953 Std: 0.016715745784488416

# %%
# --- Entrenar modelo final en todo el set (opcional) ---
final_model = make_classifier_model(input_dim=features_scaled.shape[1], num_classes=NUM_CLASSES)
final_model.fit(features_scaled, labels, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
final_model.save("yamnet_transfer_classifier.h5")
print("Modelo final guardado: yamnet_transfer_classifier.h5")
# Out:
# Epoch 1/20
# 273/273 - 2s - 6ms/step - accuracy: 0.6626 - loss: 1.4167
# Epoch 2/20
# 273/273 - 1s - 5ms/step - accuracy: 0.7615 - loss: 0.7261
# Epoch 3/20
# 273/273 - 1s - 3ms/step - accuracy: 0.7951 - loss: 0.6119
# Epoch 4/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8155 - loss: 0.5517
# Epoch 5/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8317 - loss: 0.5109
# Epoch 6/20
# 273/273 - 1s - 5ms/step - accuracy: 0.8453 - loss: 0.4635
# Epoch 7/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8518 - loss: 0.4409
# Epoch 8/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8605 - loss: 0.4260
# Epoch 9/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8653 - loss: 0.4031
# Epoch 10/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8675 - loss: 0.4039
# Epoch 11/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8810 - loss: 0.3578
# Epoch 12/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8804 - loss: 0.3626
# Epoch 13/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8873 - loss: 0.3483
# Epoch 14/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8929 - loss: 0.3267
# Epoch 15/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8926 - loss: 0.3303
# Epoch 16/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8932 - loss: 0.3323
# Epoch 17/20
# 273/273 - 1s - 5ms/step - accuracy: 0.8923 - loss: 0.3173
# Epoch 18/20
# 273/273 - 1s - 5ms/step - accuracy: 0.9036 - loss: 0.2977
# Epoch 19/20
# 273/273 - 1s - 4ms/step - accuracy: 0.9028 - loss: 0.2970
# Epoch 20/20
# 273/273 - 1s - 4ms/step - accuracy: 0.9040 - loss: 0.2892
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo final guardado: yamnet_transfer_classifier.h5
