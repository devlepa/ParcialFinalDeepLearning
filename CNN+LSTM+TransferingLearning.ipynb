# %%
import os
import numpy as np
import pandas as pd
import librosa
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers, models
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
import joblib

# %%
DATASET_PATH = "C:/Users/Estudio/Documents/ParcialFinalDeepLearning/UrbanSound8K/UrbanSound8k" # ajusta si tu dataset está en otro lugar
METADATA_CSV = os.path.join(DATASET_PATH, "metadata", "UrbanSound8K.csv")
SAMPLE_RATE = 16000            # YAMNet usa 16 kHz
DURATION = 4.0                 # segundos (igual que usabas)
NUM_CLASSES = 10
BATCH_SIZE = 32
EPOCHS = 20
RANDOM_SEED = 42

# --- Cargar metadata ---
metadata = pd.read_csv(METADATA_CSV)
metadata.columns = metadata.columns.str.strip()

# --- Cargar YAMNet (TF-Hub) ---
# Nota: esto descargará el modelo la primera vez. Requiere internet.
yamnet = hub.load("https://tfhub.dev/google/yamnet/1")
# yamnet(waveform) devuelve (scores, embeddings, spectrogram)
print("YAMNet cargado.")
# Out:
# YAMNet cargado.

# %%
def load_audio_for_yamnet(path, sr=SAMPLE_RATE, duration=DURATION):
    y, orig_sr = librosa.load(path, sr=None, mono=True)
    # Remuestrear si es necesario
    if orig_sr != sr:
        y = librosa.resample(y, orig_sr=orig_sr, target_sr=sr)
    max_len = int(sr * duration)
    if len(y) < max_len:
        y = np.pad(y, (0, max_len - len(y)))
    else:
        y = y[:max_len]
    # YAMNet espera float32 en [-1.0, 1.0]
    return y.astype(np.float32)

def extract_yamnet_embedding(waveform):
    """
    waveform: 1D numpy array a 16kHz float32
    devuelve: embedding agregado del clip (mean + std concatenadas)
    """
    # yamnet espera un tensor shape (num_samples,)
    scores, embeddings, spectrogram = yamnet(waveform)
    # embeddings: (num_patches, 1024)
    emb_np = embeddings.numpy()
    mean = np.mean(emb_np, axis=0)
    std = np.std(emb_np, axis=0)
    return np.concatenate([mean, std])  # tamaño 2048

# %%
# --- Precomputar features para todo el dataset (puede tardar) ---
features = []
labels = []
filepaths = []

for idx, row in tqdm(metadata.iterrows(), total=len(metadata), desc="Extrayendo features"):
    fold = int(row["fold"])
    filename = row["slice_file_name"]
    class_id = int(row["classID"])
    audio_path = os.path.join(DATASET_PATH, "audio", f"fold{fold}", filename)
    if not os.path.exists(audio_path):
        # opcional: omitir o lanzar error
        print("No encontrado:", audio_path)
        continue
    y = load_audio_for_yamnet(audio_path)
    emb = extract_yamnet_embedding(y)
    features.append(emb)
    labels.append(class_id)
    filepaths.append(audio_path)

features = np.array(features)   # (N, 2048)
labels = np.array(labels)
print("Features shape:", features.shape)
# Out:
# Extrayendo features: 100%|██████████| 8732/8732 [03:17<00:00, 44.28it/s]
# Features shape: (8732, 2048)

# %%
# --- Normalizar features (fit sobre todo; para CV perfecto usar pipeline) ---
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Guardar scaler para inferencia
joblib.dump(scaler, "yamnet_scaler.joblib")
print("Scaler guardado como yamnet_scaler.joblib")
# Out:
# Scaler guardado como yamnet_scaler.joblib

# %%
# --- Clasificador simple (Dense) ---
def make_classifier_model(input_dim, num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(512, activation="relu")(inputs)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# %%
# --- Validación cruzada estratificada 10-fold ---
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=RANDOM_SEED)
accs = []
fold_idx = 0

for train_idx, test_idx in skf.split(features_scaled, labels):
    fold_idx += 1
    print(f"\n=== Fold {fold_idx} ===")
    X_train, X_test = features_scaled[train_idx], features_scaled[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    model = make_classifier_model(input_dim=X_train.shape[1], num_classes=NUM_CLASSES)

    # EarlyStopping para no sobreentrenar
    es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=4, restore_best_weights=True)

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[es],
        verbose=2
    )

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold {fold_idx} accuracy: {acc:.4f}")
    accs.append(acc)
# Out:
# === Fold 1 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6640 - loss: 1.4889 - val_accuracy: 0.7723 - val_loss: 0.6107
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7502 - loss: 0.7780 - val_accuracy: 0.7689 - val_loss: 0.6021
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7773 - loss: 0.6532 - val_accuracy: 0.8112 - val_loss: 0.5512
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8095 - loss: 0.5637 - val_accuracy: 0.8330 - val_loss: 0.4713
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8194 - loss: 0.5251 - val_accuracy: 0.8398 - val_loss: 0.4864
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8332 - loss: 0.4939 - val_accuracy: 0.8455 - val_loss: 0.4102
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8418 - loss: 0.4632 - val_accuracy: 0.8501 - val_loss: 0.4503
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8579 - loss: 0.4273 - val_accuracy: 0.8661 - val_loss: 0.3910
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8584 - loss: 0.4206 - val_accuracy: 0.8799 - val_loss: 0.3685
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8628 - loss: 0.4091 - val_accuracy: 0.8982 - val_loss: 0.3281
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8791 - loss: 0.3701 - val_accuracy: 0.8650 - val_loss: 0.3777
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8806 - loss: 0.3609 - val_accuracy: 0.8856 - val_loss: 0.3415
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8785 - loss: 0.3620 - val_accuracy: 0.8730 - val_loss: 0.3644
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8733 - loss: 0.3772 - val_accuracy: 0.8661 - val_loss: 0.3856
# Fold 1 accuracy: 0.8982
#
# === Fold 2 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6607 - loss: 1.3944 - val_accuracy: 0.7632 - val_loss: 0.6477
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7541 - loss: 0.7579 - val_accuracy: 0.8261 - val_loss: 0.5321
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7895 - loss: 0.6351 - val_accuracy: 0.8284 - val_loss: 0.5020
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8039 - loss: 0.5821 - val_accuracy: 0.8604 - val_loss: 0.4457
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8226 - loss: 0.5138 - val_accuracy: 0.8730 - val_loss: 0.4045
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8381 - loss: 0.4810 - val_accuracy: 0.8673 - val_loss: 0.3944
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8399 - loss: 0.4712 - val_accuracy: 0.8764 - val_loss: 0.3768
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8523 - loss: 0.4340 - val_accuracy: 0.8684 - val_loss: 0.3782
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8539 - loss: 0.4255 - val_accuracy: 0.8753 - val_loss: 0.3628
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8647 - loss: 0.3938 - val_accuracy: 0.8799 - val_loss: 0.3725
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8637 - loss: 0.3963 - val_accuracy: 0.8719 - val_loss: 0.3752
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8678 - loss: 0.3858 - val_accuracy: 0.8696 - val_loss: 0.3836
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8716 - loss: 0.3876 - val_accuracy: 0.8753 - val_loss: 0.3804
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8819 - loss: 0.3521 - val_accuracy: 0.9016 - val_loss: 0.3190
# Epoch 15/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8895 - loss: 0.3318 - val_accuracy: 0.8867 - val_loss: 0.3767
# Epoch 16/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8899 - loss: 0.3306 - val_accuracy: 0.8959 - val_loss: 0.3349
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8880 - loss: 0.3253 - val_accuracy: 0.8913 - val_loss: 0.3519
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8889 - loss: 0.3340 - val_accuracy: 0.8890 - val_loss: 0.3533
# Fold 2 accuracy: 0.9016
#
# === Fold 3 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6587 - loss: 1.4138 - val_accuracy: 0.7606 - val_loss: 0.5983
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7507 - loss: 0.7635 - val_accuracy: 0.7892 - val_loss: 0.5786
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8655 - loss: 0.3854 - val_accuracy: 0.8763 - val_loss: 0.3559
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8725 - loss: 0.3962 - val_accuracy: 0.8763 - val_loss: 0.3457
# Fold 8 accuracy: 0.8820
#
# === Fold 9 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6641 - loss: 1.5065 - val_accuracy: 0.7812 - val_loss: 0.6478
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7534 - loss: 0.7784 - val_accuracy: 0.7915 - val_loss: 0.6097
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7839 - loss: 0.6593 - val_accuracy: 0.8270 - val_loss: 0.5679
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8076 - loss: 0.5657 - val_accuracy: 0.8270 - val_loss: 0.5484
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8233 - loss: 0.5320 - val_accuracy: 0.8339 - val_loss: 0.4620
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8381 - loss: 0.4755 - val_accuracy: 0.8499 - val_loss: 0.4182
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8519 - loss: 0.4534 - val_accuracy: 0.8660 - val_loss: 0.4184
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8551 - loss: 0.4255 - val_accuracy: 0.8740 - val_loss: 0.4090
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8691 - loss: 0.3921 - val_accuracy: 0.8855 - val_loss: 0.4043
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8613 - loss: 0.4173 - val_accuracy: 0.8660 - val_loss: 0.4340
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8669 - loss: 0.3887 - val_accuracy: 0.8786 - val_loss: 0.4250
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8798 - loss: 0.3495 - val_accuracy: 0.8729 - val_loss: 0.3927
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8819 - loss: 0.3543 - val_accuracy: 0.8671 - val_loss: 0.3939
# Fold 9 accuracy: 0.8855
#
# === Fold 10 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6601 - loss: 1.4655 - val_accuracy: 0.7675 - val_loss: 0.7038
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7542 - loss: 0.7814 - val_accuracy: 0.8477 - val_loss: 0.5131
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7936 - loss: 0.6289 - val_accuracy: 0.8362 - val_loss: 0.5626
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8080 - loss: 0.5786 - val_accuracy: 0.8236 - val_loss: 0.4892
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8256 - loss: 0.5150 - val_accuracy: 0.8648 - val_loss: 0.4373
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8440 - loss: 0.4709 - val_accuracy: 0.8454 - val_loss: 0.4511
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8524 - loss: 0.4466 - val_accuracy: 0.8717 - val_loss: 0.4054
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8560 - loss: 0.4309 - val_accuracy: 0.8855 - val_loss: 0.3930
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8649 - loss: 0.4113 - val_accuracy: 0.9015 - val_loss: 0.3476
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8655 - loss: 0.4001 - val_accuracy: 0.8855 - val_loss: 0.3857
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8810 - loss: 0.3529 - val_accuracy: 0.8912 - val_loss: 0.4086
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8837 - loss: 0.3522 - val_accuracy: 0.8946 - val_loss: 0.3620
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8885 - loss: 0.3310 - val_accuracy: 0.9072 - val_loss: 0.3394
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8848 - loss: 0.3491 - val_accuracy: 0.8969 - val_loss: 0.3944
# Epoch 15/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8952 - loss: 0.3277 - val_accuracy: 0.9049 - val_loss: 0.3315
# Epoch 16/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9023 - loss: 0.3068 - val_accuracy: 0.9107 - val_loss: 0.3717
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8985 - loss: 0.3113 - val_accuracy: 0.9026 - val_loss: 0.3472
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8960 - loss: 0.3272 - val_accuracy: 0.8981 - val_loss: 0.3997
# Epoch 19/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9097 - loss: 0.2796 - val_accuracy: 0.9095 - val_loss: 0.3166
# Epoch 20/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9077 - loss: 0.2865 - val_accuracy: 0.9095 - val_loss: 0.3699
# Fold 10 accuracy: 0.9107

# %%
# --- Resultados ---
accs = np.array(accs)
print("\nAccuracies por fold:", accs)
print("Mean accuracy:", accs.mean(), "Std:", accs.std())
# Out:
# Accuracies por fold: [0.89816934 0.90160185 0.89919817 0.88774341 0.89003438 0.89805269
#  0.89117986 0.88201606 0.88545245 0.91065294]
# Mean accuracy: 0.8944101154804229 Std: 0.008208256661899938

# %%
# --- Entrenar modelo final en todo el set (opcional) ---
final_model = make_classifier_model(
    input_dim=features_scaled.shape[1], 
    num_classes=NUM_CLASSES
)

final_model.fit(
    features_scaled, 
    labels, 
    epochs=EPOCHS, 
    batch_size=BATCH_SIZE, 
    verbose=2
)

# Exportar en formato TensorFlow SavedModel (Keras 3)
final_model.export("urban_model")

print("SavedModel generado en urban_model/")
# Out:
# Epoch 1/20
# 273/273 - 1s - 5ms/step - accuracy: 0.6724 - loss: 1.3887
# Epoch 2/20
# 273/273 - 1s - 3ms/step - accuracy: 0.7603 - loss: 0.7408
# Epoch 3/20
# 273/273 - 1s - 3ms/step - accuracy: 0.7917 - loss: 0.6304
# Epoch 4/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8154 - loss: 0.5678
# Epoch 5/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8271 - loss: 0.5178
# Epoch 6/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8472 - loss: 0.4577
# Epoch 7/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8449 - loss: 0.4658
# Epoch 8/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8587 - loss: 0.4119
# Epoch 9/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8629 - loss: 0.4120
# Epoch 10/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8719 - loss: 0.3900
# Epoch 11/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8712 - loss: 0.3784
# Epoch 12/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8737 - loss: 0.3798
# Epoch 13/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8831 - loss: 0.3536
# Epoch 14/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8880 - loss: 0.3323
# Epoch 15/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8849 - loss: 0.3537
# Epoch 16/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8965 - loss: 0.3140
# Epoch 17/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8969 - loss: 0.3171
# Epoch 18/20
# 273/273 - 1s - 3ms/step - accuracy: 0.9030 - loss: 0.3012
# Epoch 19/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8977 - loss: 0.3211
# Epoch 20/20
# 273/273 - 1s - 3ms/step - accuracy: 0.9038 - loss: 0.3037
# INFO:tensorflow:Assets written to: urban_model\assets
# INFO:tensorflow:Assets written to: urban_model\assets
# Saved artifact at 'urban_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 2048), dtype=tf.float32, name='keras_tensor_72')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   2552083816400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2552083817168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2552083816976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2552083817552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2552083816208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2552083818128: TensorSpec(shape=(), dtype=tf.resource, name=None)
# SavedModel generado en urban_model/

# %%
import tarfile

with tarfile.open("model.tar.gz", "w:gz") as tar:
    tar.add("urban_model/saved_model.pb", arcname="saved_model.pb")
    tar.add("urban_model/variables", arcname="variables")
    tar.add("yamnet_scaler.joblib", arcname="yamnet_scaler.joblib")

print("model.tar.gz creado correctamente")
# Out:
# model.tar.gz creado correctamente
