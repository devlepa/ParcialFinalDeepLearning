# %%
import os
import numpy as np
import pandas as pd
import librosa
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers, models
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
import joblib
# Out:
# c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
DATASET_PATH = "C:/Users/Estudio/Documents/ParcialFinalDeepLearning/UrbanSound8K/UrbanSound8k" # ajusta si tu dataset está en otro lugar
METADATA_CSV = os.path.join(DATASET_PATH, "metadata", "UrbanSound8K.csv")
SAMPLE_RATE = 16000            # YAMNet usa 16 kHz
DURATION = 4.0                 # segundos (igual que usabas)
NUM_CLASSES = 10
BATCH_SIZE = 32
EPOCHS = 20
RANDOM_SEED = 42

# --- Cargar metadata ---
metadata = pd.read_csv(METADATA_CSV)
metadata.columns = metadata.columns.str.strip()

# --- Cargar YAMNet (TF-Hub) ---
# Nota: esto descargará el modelo la primera vez. Requiere internet.
yamnet = hub.load("https://tfhub.dev/google/yamnet/1")
# yamnet(waveform) devuelve (scores, embeddings, spectrogram)
print("YAMNet cargado.")
# Out:
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\Estudio\Documents\ParcialFinalDeepLearning\env\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# YAMNet cargado.

# %%
def load_audio_for_yamnet(path, sr=SAMPLE_RATE, duration=DURATION):
    y, orig_sr = librosa.load(path, sr=None, mono=True)
    # Remuestrear si es necesario
    if orig_sr != sr:
        y = librosa.resample(y, orig_sr=orig_sr, target_sr=sr)
    max_len = int(sr * duration)
    if len(y) < max_len:
        y = np.pad(y, (0, max_len - len(y)))
    else:
        y = y[:max_len]
    # YAMNet espera float32 en [-1.0, 1.0]
    return y.astype(np.float32)

def extract_yamnet_embedding(waveform):
    """
    waveform: 1D numpy array a 16kHz float32
    devuelve: embedding agregado del clip (mean + std concatenadas)
    """
    # yamnet espera un tensor shape (num_samples,)
    scores, embeddings, spectrogram = yamnet(waveform)
    # embeddings: (num_patches, 1024)
    emb_np = embeddings.numpy()
    mean = np.mean(emb_np, axis=0)
    std = np.std(emb_np, axis=0)
    return np.concatenate([mean, std])  # tamaño 2048

# %%
# --- Precomputar features para todo el dataset (puede tardar) ---
features = []
labels = []
filepaths = []

for idx, row in tqdm(metadata.iterrows(), total=len(metadata), desc="Extrayendo features"):
    fold = int(row["fold"])
    filename = row["slice_file_name"]
    class_id = int(row["classID"])
    audio_path = os.path.join(DATASET_PATH, "audio", f"fold{fold}", filename)
    if not os.path.exists(audio_path):
        # opcional: omitir o lanzar error
        print("No encontrado:", audio_path)
        continue
    y = load_audio_for_yamnet(audio_path)
    emb = extract_yamnet_embedding(y)
    features.append(emb)
    labels.append(class_id)
    filepaths.append(audio_path)

features = np.array(features)   # (N, 2048)
labels = np.array(labels)
print("Features shape:", features.shape)
# Out:
# Extrayendo features: 100%|██████████| 8732/8732 [03:15<00:00, 44.72it/s]
# Features shape: (8732, 2048)

# %%
# --- Normalizar features (fit sobre todo; para CV perfecto usar pipeline) ---
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Guardar scaler para inferencia
joblib.dump(scaler, "yamnet_scaler.joblib")
# Out:
# ['yamnet_scaler.joblib']

# %%
# --- Clasificador simple (Dense) ---
def make_classifier_model(input_dim, num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(512, activation="relu")(inputs)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# %%
# --- Validación cruzada estratificada 10-fold ---
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=RANDOM_SEED)
accs = []
fold_idx = 0

for train_idx, test_idx in skf.split(features_scaled, labels):
    fold_idx += 1
    print(f"\n=== Fold {fold_idx} ===")
    X_train, X_test = features_scaled[train_idx], features_scaled[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    model = make_classifier_model(input_dim=X_train.shape[1], num_classes=NUM_CLASSES)

    # EarlyStopping para no sobreentrenar
    es = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=4, restore_best_weights=True)

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[es],
        verbose=2
    )

    loss, acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold {fold_idx} accuracy: {acc:.4f}")
    accs.append(acc)
# Out:
# === Fold 1 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6584 - loss: 1.5084 - val_accuracy: 0.7506 - val_loss: 0.6719
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7582 - loss: 0.7631 - val_accuracy: 0.8032 - val_loss: 0.5877
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7792 - loss: 0.6610 - val_accuracy: 0.8364 - val_loss: 0.4700
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8040 - loss: 0.5966 - val_accuracy: 0.8330 - val_loss: 0.4587
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8234 - loss: 0.5370 - val_accuracy: 0.8501 - val_loss: 0.4551
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8342 - loss: 0.4944 - val_accuracy: 0.8753 - val_loss: 0.3724
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8516 - loss: 0.4548 - val_accuracy: 0.8856 - val_loss: 0.3559
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8568 - loss: 0.4336 - val_accuracy: 0.8673 - val_loss: 0.4456
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8618 - loss: 0.4023 - val_accuracy: 0.8753 - val_loss: 0.3830
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8687 - loss: 0.3868 - val_accuracy: 0.8799 - val_loss: 0.3709
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8735 - loss: 0.3873 - val_accuracy: 0.8970 - val_loss: 0.3491
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8800 - loss: 0.3661 - val_accuracy: 0.8638 - val_loss: 0.4472
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8820 - loss: 0.3582 - val_accuracy: 0.8833 - val_loss: 0.3450
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8883 - loss: 0.3201 - val_accuracy: 0.9016 - val_loss: 0.3391
# Epoch 15/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8883 - loss: 0.3423 - val_accuracy: 0.8776 - val_loss: 0.3838
# Epoch 16/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8990 - loss: 0.3087 - val_accuracy: 0.8833 - val_loss: 0.3703
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9065 - loss: 0.2918 - val_accuracy: 0.9153 - val_loss: 0.2929
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8965 - loss: 0.3231 - val_accuracy: 0.9119 - val_loss: 0.3267
# Epoch 19/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9034 - loss: 0.2943 - val_accuracy: 0.8947 - val_loss: 0.4199
# Epoch 20/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9010 - loss: 0.3057 - val_accuracy: 0.9062 - val_loss: 0.3116
# Fold 1 accuracy: 0.9153
#
# === Fold 2 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6666 - loss: 1.4169 - val_accuracy: 0.7780 - val_loss: 0.6035
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7602 - loss: 0.7592 - val_accuracy: 0.8101 - val_loss: 0.5415
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7907 - loss: 0.6254 - val_accuracy: 0.8284 - val_loss: 0.4646
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8059 - loss: 0.5660 - val_accuracy: 0.8753 - val_loss: 0.3923
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8283 - loss: 0.5042 - val_accuracy: 0.8593 - val_loss: 0.4293
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8385 - loss: 0.4809 - val_accuracy: 0.8799 - val_loss: 0.3921
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8460 - loss: 0.4561 - val_accuracy: 0.8535 - val_loss: 0.4058
# Epoch 8/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8510 - loss: 0.4343 - val_accuracy: 0.8730 - val_loss: 0.3580
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8589 - loss: 0.4277 - val_accuracy: 0.8753 - val_loss: 0.3805
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8609 - loss: 0.4060 - val_accuracy: 0.8719 - val_loss: 0.3573
# Fold 2 accuracy: 0.8799
#
# === Fold 3 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6605 - loss: 1.4777 - val_accuracy: 0.7778 - val_loss: 0.6548
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7509 - loss: 0.7657 - val_accuracy: 0.8041 - val_loss: 0.5780
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7838 - loss: 0.6497 - val_accuracy: 0.7950 - val_loss: 0.5314
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8074 - loss: 0.5893 - val_accuracy: 0.8545 - val_loss: 0.4466
# Epoch 5/20
# 246/246 - 1s - 5ms/step - accuracy: 0.8221 - loss: 0.5228 - val_accuracy: 0.8603 - val_loss: 0.4172
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8235 - loss: 0.5151 - val_accuracy: 0.8591 - val_loss: 0.4453
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8507 - loss: 0.4497 - val_accuracy: 0.8900 - val_loss: 0.3687
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8497 - loss: 0.4466 - val_accuracy: 0.8866 - val_loss: 0.3878
# Epoch 9/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8505 - loss: 0.4423 - val_accuracy: 0.8774 - val_loss: 0.3579
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8628 - loss: 0.4014 - val_accuracy: 0.8843 - val_loss: 0.3248
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8736 - loss: 0.3907 - val_accuracy: 0.8534 - val_loss: 0.4292
# Fold 3 accuracy: 0.8900
#
# === Fold 4 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6626 - loss: 1.4506 - val_accuracy: 0.8007 - val_loss: 0.5942
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7476 - loss: 0.7683 - val_accuracy: 0.7961 - val_loss: 0.5982
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7852 - loss: 0.6426 - val_accuracy: 0.8328 - val_loss: 0.5411
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7986 - loss: 0.5856 - val_accuracy: 0.8328 - val_loss: 0.4642
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8165 - loss: 0.5332 - val_accuracy: 0.8385 - val_loss: 0.4608
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8222 - loss: 0.5069 - val_accuracy: 0.8454 - val_loss: 0.3946
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8423 - loss: 0.4622 - val_accuracy: 0.8603 - val_loss: 0.4416
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8509 - loss: 0.4411 - val_accuracy: 0.8786 - val_loss: 0.3965
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8542 - loss: 0.4159 - val_accuracy: 0.8820 - val_loss: 0.4085
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8625 - loss: 0.4056 - val_accuracy: 0.8843 - val_loss: 0.3581
# Epoch 11/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8720 - loss: 0.3850 - val_accuracy: 0.8797 - val_loss: 0.3704
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8762 - loss: 0.3672 - val_accuracy: 0.8637 - val_loss: 0.4016
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8799 - loss: 0.3713 - val_accuracy: 0.9003 - val_loss: 0.3875
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8889 - loss: 0.3388 - val_accuracy: 0.8694 - val_loss: 0.4359
# Epoch 15/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8855 - loss: 0.3441 - val_accuracy: 0.8946 - val_loss: 0.3425
# Epoch 16/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8981 - loss: 0.3054 - val_accuracy: 0.9015 - val_loss: 0.3226
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8911 - loss: 0.3342 - val_accuracy: 0.8855 - val_loss: 0.3586
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8952 - loss: 0.3137 - val_accuracy: 0.8946 - val_loss: 0.3462
# Epoch 19/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9023 - loss: 0.2985 - val_accuracy: 0.9061 - val_loss: 0.3292
# Epoch 20/20
# 246/246 - 1s - 4ms/step - accuracy: 0.9048 - loss: 0.2957 - val_accuracy: 0.8958 - val_loss: 0.3616
# Fold 4 accuracy: 0.9061
#
# === Fold 5 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6678 - loss: 1.5028 - val_accuracy: 0.7686 - val_loss: 0.7294
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7559 - loss: 0.7719 - val_accuracy: 0.7961 - val_loss: 0.5802
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7866 - loss: 0.6473 - val_accuracy: 0.8225 - val_loss: 0.5078
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8169 - loss: 0.5415 - val_accuracy: 0.8293 - val_loss: 0.4953
# Epoch 5/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8376 - loss: 0.4997 - val_accuracy: 0.8396 - val_loss: 0.4830
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8416 - loss: 0.4913 - val_accuracy: 0.8282 - val_loss: 0.5007
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8488 - loss: 0.4617 - val_accuracy: 0.8591 - val_loss: 0.4144
# Epoch 8/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8621 - loss: 0.4200 - val_accuracy: 0.8820 - val_loss: 0.3760
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8677 - loss: 0.4078 - val_accuracy: 0.8832 - val_loss: 0.3798
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8726 - loss: 0.3850 - val_accuracy: 0.8729 - val_loss: 0.4207
# Epoch 11/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8733 - loss: 0.3877 - val_accuracy: 0.8774 - val_loss: 0.4028
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8882 - loss: 0.3421 - val_accuracy: 0.8706 - val_loss: 0.3528
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8836 - loss: 0.3497 - val_accuracy: 0.8820 - val_loss: 0.3921
# Fold 5 accuracy: 0.8832
#
# === Fold 6 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6582 - loss: 1.4837 - val_accuracy: 0.7766 - val_loss: 0.6754
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7506 - loss: 0.7649 - val_accuracy: 0.7973 - val_loss: 0.5614
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7931 - loss: 0.6278 - val_accuracy: 0.7995 - val_loss: 0.5514
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7973 - loss: 0.5884 - val_accuracy: 0.8557 - val_loss: 0.4578
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8217 - loss: 0.5386 - val_accuracy: 0.8465 - val_loss: 0.4420
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8387 - loss: 0.4835 - val_accuracy: 0.8511 - val_loss: 0.4737
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8417 - loss: 0.4662 - val_accuracy: 0.8694 - val_loss: 0.4060
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8570 - loss: 0.4159 - val_accuracy: 0.8660 - val_loss: 0.3864
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8581 - loss: 0.4217 - val_accuracy: 0.8660 - val_loss: 0.4021
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8669 - loss: 0.3935 - val_accuracy: 0.8900 - val_loss: 0.3655
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8738 - loss: 0.3674 - val_accuracy: 0.8866 - val_loss: 0.3587
# Epoch 12/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8724 - loss: 0.3730 - val_accuracy: 0.8786 - val_loss: 0.3867
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8798 - loss: 0.3595 - val_accuracy: 0.8889 - val_loss: 0.3940
# Epoch 14/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8875 - loss: 0.3370 - val_accuracy: 0.8832 - val_loss: 0.3796
# Fold 6 accuracy: 0.8900
#
# === Fold 7 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6654 - loss: 1.4228 - val_accuracy: 0.7824 - val_loss: 0.6521
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7487 - loss: 0.7510 - val_accuracy: 0.8144 - val_loss: 0.5361
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7822 - loss: 0.6399 - val_accuracy: 0.8339 - val_loss: 0.4831
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8058 - loss: 0.5709 - val_accuracy: 0.8557 - val_loss: 0.4556
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8210 - loss: 0.5317 - val_accuracy: 0.8683 - val_loss: 0.3934
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8318 - loss: 0.4946 - val_accuracy: 0.8683 - val_loss: 0.4013
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8437 - loss: 0.4561 - val_accuracy: 0.8671 - val_loss: 0.3883
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8525 - loss: 0.4301 - val_accuracy: 0.8763 - val_loss: 0.3788
# Epoch 9/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8541 - loss: 0.4251 - val_accuracy: 0.8923 - val_loss: 0.3460
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8642 - loss: 0.3976 - val_accuracy: 0.8763 - val_loss: 0.3619
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8626 - loss: 0.4009 - val_accuracy: 0.8946 - val_loss: 0.3455
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8730 - loss: 0.3740 - val_accuracy: 0.8912 - val_loss: 0.3399
# Epoch 13/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8735 - loss: 0.3710 - val_accuracy: 0.8900 - val_loss: 0.3198
# Epoch 14/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8822 - loss: 0.3419 - val_accuracy: 0.8843 - val_loss: 0.3654
# Epoch 15/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8822 - loss: 0.3454 - val_accuracy: 0.9107 - val_loss: 0.3335
# Epoch 16/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8856 - loss: 0.3392 - val_accuracy: 0.8889 - val_loss: 0.3257
# Epoch 17/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8906 - loss: 0.3290 - val_accuracy: 0.8935 - val_loss: 0.3795
# Epoch 18/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8912 - loss: 0.3249 - val_accuracy: 0.9152 - val_loss: 0.3062
# Epoch 19/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8936 - loss: 0.3027 - val_accuracy: 0.9003 - val_loss: 0.3190
# Epoch 20/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8960 - loss: 0.3036 - val_accuracy: 0.9015 - val_loss: 0.3234
# Fold 7 accuracy: 0.9152
#
# === Fold 8 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6568 - loss: 1.3851 - val_accuracy: 0.8099 - val_loss: 0.5857
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7498 - loss: 0.7507 - val_accuracy: 0.8018 - val_loss: 0.5495
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7873 - loss: 0.6321 - val_accuracy: 0.8190 - val_loss: 0.5260
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8044 - loss: 0.5907 - val_accuracy: 0.8488 - val_loss: 0.4511
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8253 - loss: 0.5156 - val_accuracy: 0.8625 - val_loss: 0.3938
# Epoch 6/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8393 - loss: 0.4843 - val_accuracy: 0.8499 - val_loss: 0.3922
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8520 - loss: 0.4482 - val_accuracy: 0.8774 - val_loss: 0.3888
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8491 - loss: 0.4396 - val_accuracy: 0.8786 - val_loss: 0.3388
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8569 - loss: 0.4376 - val_accuracy: 0.9015 - val_loss: 0.3049
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8700 - loss: 0.3974 - val_accuracy: 0.8706 - val_loss: 0.3554
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8715 - loss: 0.3773 - val_accuracy: 0.9003 - val_loss: 0.2899
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8721 - loss: 0.3819 - val_accuracy: 0.8923 - val_loss: 0.3191
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8784 - loss: 0.3589 - val_accuracy: 0.8877 - val_loss: 0.3039
# Fold 8 accuracy: 0.9015
#
# === Fold 9 ===
# Epoch 1/20
# 246/246 - 1s - 6ms/step - accuracy: 0.6627 - loss: 1.4313 - val_accuracy: 0.7812 - val_loss: 0.6592
# Epoch 2/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7520 - loss: 0.7701 - val_accuracy: 0.8213 - val_loss: 0.5808
# Epoch 3/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7920 - loss: 0.6318 - val_accuracy: 0.8385 - val_loss: 0.5300
# Epoch 4/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8035 - loss: 0.5879 - val_accuracy: 0.8144 - val_loss: 0.5222
# Epoch 5/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8187 - loss: 0.5384 - val_accuracy: 0.8465 - val_loss: 0.4697
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8338 - loss: 0.4954 - val_accuracy: 0.8385 - val_loss: 0.4748
# Epoch 7/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8476 - loss: 0.4476 - val_accuracy: 0.8786 - val_loss: 0.4173
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8576 - loss: 0.4072 - val_accuracy: 0.8763 - val_loss: 0.4038
# Epoch 9/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8623 - loss: 0.4024 - val_accuracy: 0.8694 - val_loss: 0.4160
# Epoch 10/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8661 - loss: 0.3977 - val_accuracy: 0.8557 - val_loss: 0.4621
# Epoch 11/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8752 - loss: 0.3693 - val_accuracy: 0.8729 - val_loss: 0.4138
# Fold 9 accuracy: 0.8786
#
# === Fold 10 ===
# Epoch 1/20
# 246/246 - 2s - 7ms/step - accuracy: 0.6610 - loss: 1.4856 - val_accuracy: 0.7583 - val_loss: 0.6681
# Epoch 2/20
# 246/246 - 1s - 3ms/step - accuracy: 0.7581 - loss: 0.7493 - val_accuracy: 0.7824 - val_loss: 0.6680
# Epoch 3/20
# 246/246 - 1s - 4ms/step - accuracy: 0.7762 - loss: 0.6572 - val_accuracy: 0.8499 - val_loss: 0.5518
# Epoch 4/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8113 - loss: 0.5677 - val_accuracy: 0.8511 - val_loss: 0.5214
# Epoch 5/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8277 - loss: 0.5154 - val_accuracy: 0.8351 - val_loss: 0.4805
# Epoch 6/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8364 - loss: 0.4797 - val_accuracy: 0.8408 - val_loss: 0.4232
# Epoch 7/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8482 - loss: 0.4455 - val_accuracy: 0.8614 - val_loss: 0.4394
# Epoch 8/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8632 - loss: 0.4164 - val_accuracy: 0.8683 - val_loss: 0.4066
# Epoch 9/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8625 - loss: 0.4145 - val_accuracy: 0.8923 - val_loss: 0.3893
# Epoch 10/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8647 - loss: 0.4015 - val_accuracy: 0.8648 - val_loss: 0.3882
# Epoch 11/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8728 - loss: 0.3946 - val_accuracy: 0.8717 - val_loss: 0.4025
# Epoch 12/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8826 - loss: 0.3495 - val_accuracy: 0.8981 - val_loss: 0.3638
# Epoch 13/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8822 - loss: 0.3509 - val_accuracy: 0.8958 - val_loss: 0.3563
# Epoch 14/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8813 - loss: 0.3468 - val_accuracy: 0.8923 - val_loss: 0.3504
# Epoch 15/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8879 - loss: 0.3446 - val_accuracy: 0.9015 - val_loss: 0.3736
# Epoch 16/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8894 - loss: 0.3237 - val_accuracy: 0.8912 - val_loss: 0.3899
# Epoch 17/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8925 - loss: 0.3168 - val_accuracy: 0.9026 - val_loss: 0.3298
# Epoch 18/20
# 246/246 - 1s - 4ms/step - accuracy: 0.8901 - loss: 0.3300 - val_accuracy: 0.8797 - val_loss: 0.4333
# Epoch 19/20
# 246/246 - 1s - 3ms/step - accuracy: 0.8925 - loss: 0.3216 - val_accuracy: 0.8717 - val_loss: 0.4412
# Epoch 20/20
# 246/246 - 1s - 3ms/step - accuracy: 0.9070 - loss: 0.2893 - val_accuracy: 0.8923 - val_loss: 0.3981
# Fold 10 accuracy: 0.9026

# %%
# --- Resultados ---
accs = np.array(accs)
print("\nAccuracies por fold:", accs)
print("Mean accuracy:", accs.mean(), "Std:", accs.std())
# Out:
# Accuracies por fold: [0.91533178 0.87986273 0.89003438 0.90607101 0.88316149 0.89003438
#  0.9152348  0.90148914 0.87857962 0.90263462]
# Mean accuracy: 0.8962433934211731 Std: 0.013109398178722738

# %%
# --- Entrenar modelo final en todo el set (opcional) ---
final_model = make_classifier_model(input_dim=features_scaled.shape[1], num_classes=NUM_CLASSES)
final_model.fit(features_scaled, labels, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
model.export("export/1")
print("Modelo final guardadoexport/1")
# Out:
# Epoch 1/20
# 273/273 - 1s - 5ms/step - accuracy: 0.6727 - loss: 1.4061
# Epoch 2/20
# 273/273 - 1s - 4ms/step - accuracy: 0.7610 - loss: 0.7519
# Epoch 3/20
# 273/273 - 1s - 4ms/step - accuracy: 0.7934 - loss: 0.6373
# Epoch 4/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8106 - loss: 0.5600
# Epoch 5/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8249 - loss: 0.5289
# Epoch 6/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8409 - loss: 0.4734
# Epoch 7/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8539 - loss: 0.4370
# Epoch 8/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8523 - loss: 0.4316
# Epoch 9/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8628 - loss: 0.4017
# Epoch 10/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8715 - loss: 0.3810
# Epoch 11/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8793 - loss: 0.3641
# Epoch 12/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8830 - loss: 0.3569
# Epoch 13/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8862 - loss: 0.3541
# Epoch 14/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8850 - loss: 0.3455
# Epoch 15/20
# 273/273 - 1s - 3ms/step - accuracy: 0.8948 - loss: 0.3079
# Epoch 16/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8850 - loss: 0.3604
# Epoch 17/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8969 - loss: 0.3186
# Epoch 18/20
# 273/273 - 1s - 4ms/step - accuracy: 0.9017 - loss: 0.3056
# Epoch 19/20
# 273/273 - 1s - 5ms/step - accuracy: 0.9012 - loss: 0.3050
# Epoch 20/20
# 273/273 - 1s - 4ms/step - accuracy: 0.8993 - loss: 0.3038
# INFO:tensorflow:Assets written to: export/1\assets
# INFO:tensorflow:Assets written to: export/1\assets
# Saved artifact at 'export/1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 2048), dtype=tf.float32, name='keras_tensor_54')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   1668949761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1668949767376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1668949765264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1668949765072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1668949760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1668949763344: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo final guardadoexport/1
